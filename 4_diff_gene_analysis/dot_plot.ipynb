# %%
import scanpy as sc

# %%
data = sc.read("../3_UMAP/UMAP_data_0.3_res.h5ad")

# %%
# Obtain cluster-specific differentially expressed genes
sc.tl.rank_genes_groups(data, groupby="leiden", method="wilcoxon")

name = "../4_diff_gene_analysis/diff_gene_data.h5ad"
data.write(name)

# %%
sc.pl.rank_genes_groups_dotplot(data, groupby="leiden", standard_scale="var", n_genes=5)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_leiden). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.

# %% [markdown]
# Analysis
